# %% [markdown]
# ## Import Library

# %%
# !git clone https://github.com/rajeevratan84/image-segmentation-keras.git
# Out:
# Cloning into 'image-segmentation-keras'...
# remote: Enumerating objects: 1165, done.
# remote: Total 1165 (delta 0), reused 0 (delta 0), pack-reused 1165
# Receiving objects: 100% (1165/1165), 3.29 MiB | 10.05 MiB/s, done.
# Resolving deltas: 100% (752/752), done.

# %%
# %cd image-segmentation-keras
# !python setup.py install
# Out:
# /kaggle/working/image-segmentation-keras

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from imgaug import augmenters as iaa
from keras.callbacks import ModelCheckpoint
from IPython.display import Image
import tensorflow as tf
from tensorflow.keras import backend as K
from keras_segmentation.models.fcn import fcn_8, fcn_8_vgg, fcn_8_resnet50, fcn_8_mobilenet
from tensorflow.keras.optimizers import Adam
import time
# Out:
# 2024-07-31 10:10:27.456958: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-31 10:10:27.457059: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-31 10:10:27.581539: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !pip list

# %%
image_train_list = os.listdir('/kaggle/input/images_train_cleaned')
anns_train_list = os.listdir('/kaggle/input/annotations_train')
image_val_list = os.listdir('/kaggle/input/images_test')
anns_val_list = os.listdir('/kaggle/input/annotations_test')

print('number of train data pairs: ', len(set(image_train_list).intersection(anns_train_list)))
print('number of validation data pairs: ', len(set(image_val_list).intersection(anns_val_list)))
del image_train_list, anns_train_list, image_val_list, anns_val_list
# Out:
# number of train data pairs:  367
# number of validation data pairs:  101

# %%
def dice_loss(y_true, y_pred, smooth=1e-6):
    """
    Calculate Dice Loss between the ground truth and predictions.

    Parameters:
    - y_true: Ground truth labels (shape: [batch_size, height, width, num_classes])
    - y_pred: Predicted labels (shape: [batch_size, height, width, num_classes])
    - smooth: Smoothing factor to avoid division by zero

    Returns:
    - Dice Loss value
    """
    # Flatten the tensors
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(y_pred)

    # Calculate intersection and union
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f)

    # Compute Dice coefficient
    dice = (2. * intersection + smooth) / (union + smooth)

    # Return Dice Loss
    return 1 - dice

# %%
model = fcn_8_resnet50(n_classes=30, input_height=352, input_width=480)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94653016/94653016 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
def custom_augmentation():
    return iaa.Sequential(
        [
            # apply the following augmenters to most images
#             iaa.GaussianBlur(sigma=(0.0, 0.5)),
            iaa.Fliplr(0.5), # horizontally flip 50% of all images
            iaa.GammaContrast((0.5, 2.0)),
            iaa.convolutional.Sharpen(alpha=(0.0, 0.2), lightness=(0.8, 1.2)),
#             iaa.Grayscale(alpha=(0.0, 1.0)),
#             iaa.pillike.FilterFindEdges(),
#             iaa.ShearX((-20, 20)),
#             iaa.AdditiveGaussianNoise(scale=(0, 0.1*255)),
#             iaa.Canny(alpha=(0.0, 0.5),colorizer=iaa.RandomColorsBinaryImageColorizer(color_true=255,color_false=0)),
        ])
# [sharpness, contrast], blur (jgn terlalu blur), saturation, hue

def image_preprocessing(image):
    image = tf.cast(image, tf.float32)
    scaled_image = image.numpy() / 255.0
    return scaled_image

# %%
from keras_segmentation.data_utils.data_loader import image_segmentation_generator, verify_segmentation_dataset
train_gen = image_segmentation_generator(images_path = "/kaggle/input/images_train_cleaned/", 
                                         segs_path = "/kaggle/input/annotations_train/",  
                                         batch_size = 2,  
                                         n_classes = 30,
                                         input_height = 352, 
                                         input_width = 480, 
                                         output_height = model.output_height, 
                                         output_width = model.output_width,
                                         do_augment=False, 
#                                          augmentation_name=augmentation_name,
#                                          custom_augmentation=custom_augmentation, 
#                                          other_inputs_paths=other_inputs_paths,
#                                          preprocessing=image_preprocessing, 
                                         read_image_type=1)

val_gen = image_segmentation_generator(images_path = "/kaggle/input/images_test/", 
                                       segs_path = "/kaggle/input/annotations_test/",  
                                       batch_size = 2,
                                       n_classes = 30, 
                                       input_height = 352, 
                                       input_width = 480, 
                                       output_height = model.output_height, 
                                       output_width = model.output_width,
                                       do_augment = False,
#                                          augmentation_name=augmentation_name,
#                                          custom_augmentation=custom_augmentation, 
#                                          other_inputs_paths=other_inputs_paths,
#                                          preprocessing=image_preprocessing, 
                                       read_image_type=1)

# %%
verify_segmentation_dataset(images_path = "/kaggle/input/images_train_cleaned/",
                            segs_path = "/kaggle/input/annotations_train/",
                            n_classes = 30)
verify_segmentation_dataset(images_path = "/kaggle/input/images_test/",
                            segs_path = "/kaggle/input/annotations_test/",
                            n_classes = 30)
# Out:
# 100%|██████████| 367/367 [00:08<00:00, 42.90it/s]
# Dataset verified!
# 100%|██████████| 101/101 [00:02<00:00, 43.62it/s]
# Dataset verified!
# True

# %%
checkpoint_path = "/kaggle/working/weights/resnet50_fcn8.weights.h5"
os.makedirs(os.path.dirname(checkpoint_path), exist_ok = True)
checkpoint = ModelCheckpoint(checkpoint_path, 
                             monitor="val_dice_loss",
                             save_best_only=True,
                             save_weights_only = True,
                             mode="min")

# %%
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',#dice_loss,
    metrics=[dice_loss, 'accuracy']#, tf.keras.metrics.F1Score(average = "weighted")] # f1-score, accuracy
)

start_time = time.time()
model.fit(train_gen,
          steps_per_epoch = 512,
          validation_data=val_gen,
          validation_steps=512,
          epochs = 10, # coba 20 epoch u/ cek overfitting
          callbacks=[checkpoint],
          initial_epoch=0)
print('training completed in {} s'.format(time.time()-start_time))
# Out:
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1722420740.628161     114 hlo_rematerialization.cc:2946] Can't reduce memory use below 6.33GiB (6794946603 bytes) by rematerialization; only reduced to 11.17GiB (11995553072 bytes), down from 11.17GiB (11998368080 bytes) originally
# I0000 00:00:1722420755.711286     114 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 567s 917ms/step - accuracy: 0.6352 - dice_loss: 0.4519 - loss: 1.2177 - val_accuracy: 0.8814 - val_dice_loss: 0.1662 - val_loss: 0.3791
# Epoch 2/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 469s 916ms/step - accuracy: 0.9085 - dice_loss: 0.1350 - loss: 0.2821 - val_accuracy: 0.9033 - val_dice_loss: 0.1269 - val_loss: 0.3085
# Epoch 3/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 472s 923ms/step - accuracy: 0.9290 - dice_loss: 0.1042 - loss: 0.2097 - val_accuracy: 0.9158 - val_dice_loss: 0.1087 - val_loss: 0.2687
# Epoch 4/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 448s 875ms/step - accuracy: 0.9361 - dice_loss: 0.0924 - loss: 0.1827 - val_accuracy: 0.9105 - val_dice_loss: 0.1117 - val_loss: 0.2978
# Epoch 5/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 444s 867ms/step - accuracy: 0.9427 - dice_loss: 0.0825 - loss: 0.1608 - val_accuracy: 0.8962 - val_dice_loss: 0.1322 - val_loss: 0.3722
# Epoch 6/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 453s 886ms/step - accuracy: 0.9478 - dice_loss: 0.0751 - loss: 0.1441 - val_accuracy: 0.9126 - val_dice_loss: 0.1059 - val_loss: 0.2986
# Epoch 7/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 426s 832ms/step - accuracy: 0.9526 - dice_loss: 0.0680 - loss: 0.1282 - val_accuracy: 0.9105 - val_dice_loss: 0.1122 - val_loss: 0.3214
# Epoch 8/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 446s 871ms/step - accuracy: 0.9530 - dice_loss: 0.0668 - loss: 0.1268 - val_accuracy: 0.9153 - val_dice_loss: 0.1001 - val_loss: 0.2926
# Epoch 9/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 442s 863ms/step - accuracy: 0.9551 - dice_loss: 0.0635 - loss: 0.1197 - val_accuracy: 0.9209 - val_dice_loss: 0.0966 - val_loss: 0.2682
# Epoch 10/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 437s 853ms/step - accuracy: 0.9579 - dice_loss: 0.0598 - loss: 0.1116 - val_accuracy: 0.9199 - val_dice_loss: 0.0961 - val_loss: 0.2911
# training completed in 4604.27500462532 s

# %%
print(model.history.history.keys())
# Out:
# dict_keys(['accuracy', 'dice_loss', 'loss', 'val_accuracy', 'val_dice_loss', 'val_loss'])

# %%
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(model.history.history['dice_loss'])
plt.plot(model.history.history['val_dice_loss'])
plt.title('model dice loss')
plt.ylabel('dice loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
out = model.predict_segmentation(
    inp = "/kaggle/input/images_test/0016E5_07959.png"
)
plt.imshow(out)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step

# %%
from IPython.display import Image

o = model.predict_segmentation(
    inp="/kaggle/input/images_test/0016E5_07959.png",
    out_fname="/kaggle/working/out.png",
    overlay_img=True,
    show_legends=True,
    class_names = ["Sky","Building","Pole","Road","pavement","Tree","SignSymbol","Fence","Car","Pedestrian","Bicylist"]
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
Image("/kaggle/working/out.png")
