# %% [markdown]
# ## Import Library

# %%
# !git clone https://github.com/rajeevratan84/image-segmentation-keras.git
# Out:
# Cloning into 'image-segmentation-keras'...
# remote: Enumerating objects: 1165, done.
# remote: Total 1165 (delta 0), reused 0 (delta 0), pack-reused 1165
# Receiving objects: 100% (1165/1165), 3.29 MiB | 37.42 MiB/s, done.
# Resolving deltas: 100% (752/752), done.

# %%
# %cd image-segmentation-keras
# !python setup.py install
# Out:
# /kaggle/working/image-segmentation-keras

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from imgaug import augmenters as iaa
from keras.callbacks import ModelCheckpoint
from IPython.display import Image
import tensorflow as tf
from tensorflow.keras import backend as K
from keras_segmentation.models.fcn import fcn_8, fcn_8_vgg, fcn_8_resnet50, fcn_8_mobilenet
from tensorflow.keras.optimizers import Adam
import time
# Out:
# 2024-07-30 16:40:44.760417: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-30 16:40:44.760523: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-30 16:40:44.901734: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !pip list

# %%
image_train_list = os.listdir('/kaggle/input/images_train_cleaned')
anns_train_list = os.listdir('/kaggle/input/annotations_train')
image_val_list = os.listdir('/kaggle/input/images_test')
anns_val_list = os.listdir('/kaggle/input/annotations_test')

print('number of train data pairs: ', len(set(image_train_list).intersection(anns_train_list)))
print('number of validation data pairs: ', len(set(image_val_list).intersection(anns_val_list)))
del image_train_list, anns_train_list, image_val_list, anns_val_list
# Out:
# number of train data pairs:  367
# number of validation data pairs:  101

# %%
def dice_loss(y_true, y_pred, smooth=1e-6):
    """
    Calculate Dice Loss between the ground truth and predictions.

    Parameters:
    - y_true: Ground truth labels (shape: [batch_size, height, width, num_classes])
    - y_pred: Predicted labels (shape: [batch_size, height, width, num_classes])
    - smooth: Smoothing factor to avoid division by zero

    Returns:
    - Dice Loss value
    """
    # Flatten the tensors
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(y_pred)

    # Calculate intersection and union
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f)

    # Compute Dice coefficient
    dice = (2. * intersection + smooth) / (union + smooth)

    # Return Dice Loss
    return 1 - dice

# %%
model = fcn_8(n_classes=30, input_height=352, input_width=480)

# %%
def custom_augmentation():
    return iaa.Sequential(
        [
            # apply the following augmenters to most images
#             iaa.GaussianBlur(sigma=(0.0, 0.5)),
            iaa.Fliplr(0.5), # horizontally flip 50% of all images
            iaa.GammaContrast((0.5, 2.0)),
            iaa.convolutional.Sharpen(alpha=(0.0, 0.2), lightness=(0.8, 1.2)),
#             iaa.Grayscale(alpha=(0.0, 1.0)),
#             iaa.pillike.FilterFindEdges(),
#             iaa.ShearX((-20, 20)),
#             iaa.AdditiveGaussianNoise(scale=(0, 0.1*255)),
#             iaa.Canny(alpha=(0.0, 0.5),colorizer=iaa.RandomColorsBinaryImageColorizer(color_true=255,color_false=0)),
        ])
# [sharpness, contrast], blur (jgn terlalu blur), saturation, hue

def image_preprocessing(image):
    image = tf.cast(image, tf.float32)
    scaled_image = image.numpy() / 255.0
    return scaled_image

# %%
from keras_segmentation.data_utils.data_loader import image_segmentation_generator, verify_segmentation_dataset
train_gen = image_segmentation_generator(images_path = "/kaggle/input/images_train_cleaned/", 
                                         segs_path = "/kaggle/input/annotations_train/",  
                                         batch_size = 2,  
                                         n_classes = 30,
                                         input_height = 352, 
                                         input_width = 480, 
                                         output_height = model.output_height, 
                                         output_width = model.output_width,
                                         do_augment=False, 
#                                          augmentation_name=augmentation_name,
#                                          custom_augmentation=custom_augmentation, 
#                                          other_inputs_paths=other_inputs_paths,
#                                          preprocessing=image_preprocessing, 
                                         read_image_type=1)

val_gen = image_segmentation_generator(images_path = "/kaggle/input/images_test/", 
                                       segs_path = "/kaggle/input/annotations_test/",  
                                       batch_size = 2,
                                       n_classes = 30, 
                                       input_height = 352, 
                                       input_width = 480, 
                                       output_height = model.output_height, 
                                       output_width = model.output_width,
                                       do_augment = False,
#                                          augmentation_name=augmentation_name,
#                                          custom_augmentation=custom_augmentation, 
#                                          other_inputs_paths=other_inputs_paths,
#                                          preprocessing=image_preprocessing, 
                                       read_image_type=1)

# %%
verify_segmentation_dataset(images_path = "/kaggle/input/images_train_cleaned/",
                            segs_path = "/kaggle/input/annotations_train/",
                            n_classes = 30)
verify_segmentation_dataset(images_path = "/kaggle/input/images_test/",
                            segs_path = "/kaggle/input/annotations_test/",
                            n_classes = 30)
# Out:
# 100%|██████████| 367/367 [00:07<00:00, 51.92it/s]
# Dataset verified!
# 100%|██████████| 101/101 [00:01<00:00, 54.26it/s]
# Dataset verified!
# True

# %%
checkpoint_path = "/kaggle/working/weights/vanilla_fcn8.weights.h5"
os.makedirs(os.path.dirname(checkpoint_path), exist_ok = True)
checkpoint = ModelCheckpoint(checkpoint_path, 
                             monitor="val_dice_loss",
                             save_best_only=True,
                             save_weights_only = True,
                             mode="min")

# %%
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',#dice_loss,
    metrics=[dice_loss, 'accuracy']#, tf.keras.metrics.F1Score(average = "weighted")] # f1-score, accuracy
)

start_time = time.time()
model.fit(train_gen,
          steps_per_epoch = 512,
          validation_data=val_gen,
          validation_steps=512,
          epochs = 10, # coba 20 epoch u/ cek overfitting
          callbacks=[checkpoint],
          initial_epoch=0)
print('training completed in {} s'.format(time.time()-start_time))
# Out:
# Epoch 1/10
#   1/512 ━━━━━━━━━━━━━━━━━━━━ 4:13:32 30s/step - accuracy: 0.0308 - dice_loss: 0.9666 - loss: 3.4186
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722357696.275136     125 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 351s 629ms/step - accuracy: 0.5816 - dice_loss: 0.5325 - loss: 1.4101 - val_accuracy: 0.7731 - val_dice_loss: 0.3169 - val_loss: 0.7698
# Epoch 2/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 321s 628ms/step - accuracy: 0.8263 - dice_loss: 0.2551 - loss: 0.5679 - val_accuracy: 0.8500 - val_dice_loss: 0.2430 - val_loss: 0.5108
# Epoch 3/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 312s 611ms/step - accuracy: 0.8578 - dice_loss: 0.2092 - loss: 0.4598 - val_accuracy: 0.8526 - val_dice_loss: 0.2152 - val_loss: 0.4913
# Epoch 4/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 324s 634ms/step - accuracy: 0.8761 - dice_loss: 0.1818 - loss: 0.3925 - val_accuracy: 0.8771 - val_dice_loss: 0.1786 - val_loss: 0.3796
# Epoch 5/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 318s 622ms/step - accuracy: 0.8897 - dice_loss: 0.1631 - loss: 0.3463 - val_accuracy: 0.8656 - val_dice_loss: 0.1848 - val_loss: 0.4216
# Epoch 6/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 312s 609ms/step - accuracy: 0.9004 - dice_loss: 0.1474 - loss: 0.3092 - val_accuracy: 0.8777 - val_dice_loss: 0.1810 - val_loss: 0.3817
# Epoch 7/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 301s 588ms/step - accuracy: 0.9093 - dice_loss: 0.1351 - loss: 0.2801 - val_accuracy: 0.8697 - val_dice_loss: 0.1709 - val_loss: 0.4417
# Epoch 8/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 273s 535ms/step - accuracy: 0.9114 - dice_loss: 0.1303 - loss: 0.2687 - val_accuracy: 0.8356 - val_dice_loss: 0.1874 - val_loss: 0.5840
# Epoch 9/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 280s 548ms/step - accuracy: 0.9168 - dice_loss: 0.1218 - loss: 0.2500 - val_accuracy: 0.8704 - val_dice_loss: 0.1599 - val_loss: 0.4303
# Epoch 10/10
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 264s 516ms/step - accuracy: 0.9205 - dice_loss: 0.1169 - loss: 0.2371 - val_accuracy: 0.8897 - val_dice_loss: 0.1362 - val_loss: 0.3746
# training completed in 3058.4162046909332 s

# %%
print(model.history.history.keys())
# Out:
# dict_keys(['accuracy', 'dice_loss', 'loss', 'val_accuracy', 'val_dice_loss', 'val_loss'])

# %%
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(model.history.history['dice_loss'])
plt.plot(model.history.history['val_dice_loss'])
plt.title('model dice loss')
plt.ylabel('dice loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
out = model.predict_segmentation(
    inp = "/kaggle/input/images_test/0016E5_07959.png"
)
plt.imshow(out)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %%
from IPython.display import Image

o = model.predict_segmentation(
    inp="/kaggle/input/images_test/0016E5_07959.png",
    out_fname="/kaggle/working/out.png",
    overlay_img=True,
    show_legends=True,
    class_names = ["Sky","Building","Pole","Road","pavement","Tree","SignSymbol","Fence","Car","Pedestrian","Bicylist"]
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
Image("/kaggle/working/out.png")
