# %% [markdown]
# ## Import Library

# %%
# !git clone https://github.com/rajeevratan84/image-segmentation-keras.git
# Out:
# Cloning into 'image-segmentation-keras'...
# remote: Enumerating objects: 1165, done.
# remote: Total 1165 (delta 0), reused 0 (delta 0), pack-reused 1165
# Receiving objects: 100% (1165/1165), 3.29 MiB | 12.12 MiB/s, done.
# Resolving deltas: 100% (752/752), done.

# %%
# %cd image-segmentation-keras
# !python setup.py install
# Out:
# /kaggle/working/image-segmentation-keras

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from imgaug import augmenters as iaa
from keras.callbacks import ModelCheckpoint
from IPython.display import Image
import tensorflow as tf
from tensorflow.keras import backend as K
from keras_segmentation.models.unet import resnet50_unet
from tensorflow.keras.optimizers import Adam
import time
# Out:
# 2024-08-04 12:01:34.813560: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-04 12:01:34.813660: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-04 12:01:34.979625: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !pip list

# %%
image_train_list = os.listdir('/kaggle/input/images_train_cleaned')
anns_train_list = os.listdir('/kaggle/input/annotations_train')
image_val_list = os.listdir('/kaggle/input/images_test')
anns_val_list = os.listdir('/kaggle/input/annotations_test')

print('number of train data pairs: ', len(set(image_train_list).intersection(anns_train_list)))
print('number of validation data pairs: ', len(set(image_val_list).intersection(anns_val_list)))
del image_train_list, anns_train_list, image_val_list, anns_val_list
# Out:
# number of train data pairs:  367
# number of validation data pairs:  101

# %%
def dice_loss(y_true, y_pred, smooth=1e-6):
    """
    Calculate Dice Loss between the ground truth and predictions.

    Parameters:
    - y_true: Ground truth labels (shape: [batch_size, height, width, num_classes])
    - y_pred: Predicted labels (shape: [batch_size, height, width, num_classes])
    - smooth: Smoothing factor to avoid division by zero

    Returns:
    - Dice Loss value
    """
    # Flatten the tensors
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(y_pred)

    # Calculate intersection and union
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f)

    # Compute Dice coefficient
    dice = (2. * intersection + smooth) / (union + smooth)

    # Return Dice Loss
    return 1 - dice

# %%
model = resnet50_unet(n_classes=30, input_height=352, input_width=480)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94653016/94653016 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
def custom_augmentation():
    return iaa.Sequential(
        [
            # apply the following augmenters to most images
#             iaa.GaussianBlur(sigma=(0.0, 0.5)),
            iaa.Fliplr(0.5), # horizontally flip 50% of all images
            iaa.GammaContrast((0.5, 2.0)),
            iaa.convolutional.Sharpen(alpha=(0.0, 0.2), lightness=(0.8, 1.2)),
#             iaa.Grayscale(alpha=(0.0, 1.0)),
#             iaa.pillike.FilterFindEdges(),
#             iaa.ShearX((-20, 20)),
#             iaa.AdditiveGaussianNoise(scale=(0, 0.1*255)),
#             iaa.Canny(alpha=(0.0, 0.5),colorizer=iaa.RandomColorsBinaryImageColorizer(color_true=255,color_false=0)),
        ])
# [sharpness, contrast], blur (jgn terlalu blur), saturation, hue

def image_preprocessing(image):
    image = tf.cast(image, tf.float32)
    scaled_image = image.numpy() / 255.0
    return scaled_image

# %%
from keras_segmentation.data_utils.data_loader import image_segmentation_generator, verify_segmentation_dataset
train_gen = image_segmentation_generator(images_path = "/kaggle/input/images_train_cleaned/", 
                                         segs_path = "/kaggle/input/annotations_train/",  
                                         batch_size = 2,  
                                         n_classes = 30,
                                         input_height = 352, 
                                         input_width = 480, 
                                         output_height = model.output_height, 
                                         output_width = model.output_width,
                                         do_augment=True, 
#                                          augmentation_name=augmentation_name,
                                         custom_augmentation=custom_augmentation, 
#                                          other_inputs_paths=other_inputs_paths,
#                                          preprocessing=image_preprocessing, 
                                         read_image_type=1)

val_gen = image_segmentation_generator(images_path = "/kaggle/input/images_test/", 
                                       segs_path = "/kaggle/input/annotations_test/",  
                                       batch_size = 2,
                                       n_classes = 30, 
                                       input_height = 352, 
                                       input_width = 480, 
                                       output_height = model.output_height, 
                                       output_width = model.output_width,
                                       do_augment = False,
#                                          augmentation_name=augmentation_name,
#                                          custom_augmentation=custom_augmentation, 
#                                          other_inputs_paths=other_inputs_paths,
#                                          preprocessing=image_preprocessing, 
                                       read_image_type=1)

# %%
verify_segmentation_dataset(images_path = "/kaggle/input/images_train_cleaned/",
                            segs_path = "/kaggle/input/annotations_train/",
                            n_classes = 30)
verify_segmentation_dataset(images_path = "/kaggle/input/images_test/",
                            segs_path = "/kaggle/input/annotations_test/",
                            n_classes = 30)
# Out:
# 100%|██████████| 367/367 [00:07<00:00, 45.91it/s]
# Dataset verified!
# 100%|██████████| 101/101 [00:02<00:00, 44.70it/s]
# Dataset verified!
# True

# %%
checkpoint_path = "/kaggle/working/weights/resnet50_unet.weights.h5"
os.makedirs(os.path.dirname(checkpoint_path), exist_ok = True)
checkpoint = ModelCheckpoint(checkpoint_path, 
                             monitor="val_dice_loss",
                             save_best_only=True,
                             save_weights_only = True,
                             mode="min")

# %%
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',#dice_loss,
    metrics=[dice_loss, 'accuracy']#, tf.keras.metrics.F1Score(average = "weighted")] # f1-score, accuracy
)

start_time = time.time()
model.fit(train_gen,
          steps_per_epoch = 512,
          validation_data=val_gen,
          validation_steps=512,
          epochs = 20, # coba 20 epoch u/ cek overfitting
          callbacks=[checkpoint],
          initial_epoch=0)
print('training completed in {} s'.format(time.time()-start_time))
# Out:
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722772995.076227     114 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 169s 184ms/step - accuracy: 0.5867 - dice_loss: 0.5843 - loss: 1.7611 - val_accuracy: 0.8563 - val_dice_loss: 0.2264 - val_loss: 0.5156
# Epoch 2/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 90s 176ms/step - accuracy: 0.8935 - dice_loss: 0.1654 - loss: 0.3804 - val_accuracy: 0.8967 - val_dice_loss: 0.1317 - val_loss: 0.3275
# Epoch 3/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 91s 177ms/step - accuracy: 0.9228 - dice_loss: 0.1168 - loss: 0.2527 - val_accuracy: 0.9174 - val_dice_loss: 0.1136 - val_loss: 0.2714
# Epoch 4/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 91s 178ms/step - accuracy: 0.9384 - dice_loss: 0.0915 - loss: 0.1931 - val_accuracy: 0.9157 - val_dice_loss: 0.1015 - val_loss: 0.2789
# Epoch 5/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 90s 176ms/step - accuracy: 0.9454 - dice_loss: 0.0800 - loss: 0.1647 - val_accuracy: 0.9149 - val_dice_loss: 0.0989 - val_loss: 0.2835
# Epoch 6/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 89s 174ms/step - accuracy: 0.9506 - dice_loss: 0.0715 - loss: 0.1450 - val_accuracy: 0.9210 - val_dice_loss: 0.0940 - val_loss: 0.2909
# Epoch 7/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 88s 172ms/step - accuracy: 0.9555 - dice_loss: 0.0637 - loss: 0.1271 - val_accuracy: 0.9226 - val_dice_loss: 0.0922 - val_loss: 0.2798
# Epoch 8/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 84s 165ms/step - accuracy: 0.9571 - dice_loss: 0.0611 - loss: 0.1211 - val_accuracy: 0.9229 - val_dice_loss: 0.0931 - val_loss: 0.2811
# Epoch 9/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 82s 161ms/step - accuracy: 0.9602 - dice_loss: 0.0566 - loss: 0.1103 - val_accuracy: 0.9197 - val_dice_loss: 0.0922 - val_loss: 0.2946
# Epoch 10/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 82s 160ms/step - accuracy: 0.9611 - dice_loss: 0.0548 - loss: 0.1067 - val_accuracy: 0.9106 - val_dice_loss: 0.1013 - val_loss: 0.3125
# Epoch 11/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 82s 160ms/step - accuracy: 0.9589 - dice_loss: 0.0583 - loss: 0.1138 - val_accuracy: 0.9200 - val_dice_loss: 0.0934 - val_loss: 0.3451
# Epoch 12/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 83s 162ms/step - accuracy: 0.9654 - dice_loss: 0.0490 - loss: 0.0928 - val_accuracy: 0.9252 - val_dice_loss: 0.0855 - val_loss: 0.2938
# Epoch 13/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 82s 160ms/step - accuracy: 0.9667 - dice_loss: 0.0471 - loss: 0.0889 - val_accuracy: 0.9180 - val_dice_loss: 0.0906 - val_loss: 0.3379
# Epoch 14/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 82s 160ms/step - accuracy: 0.9673 - dice_loss: 0.0460 - loss: 0.0871 - val_accuracy: 0.9210 - val_dice_loss: 0.0886 - val_loss: 0.3321
# Epoch 15/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 82s 160ms/step - accuracy: 0.9680 - dice_loss: 0.0449 - loss: 0.0846 - val_accuracy: 0.9219 - val_dice_loss: 0.0872 - val_loss: 0.3346
# Epoch 16/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 83s 162ms/step - accuracy: 0.9652 - dice_loss: 0.0485 - loss: 0.0936 - val_accuracy: 0.9244 - val_dice_loss: 0.0837 - val_loss: 0.3057
# Epoch 17/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 82s 160ms/step - accuracy: 0.9679 - dice_loss: 0.0454 - loss: 0.0853 - val_accuracy: 0.9242 - val_dice_loss: 0.0850 - val_loss: 0.3055
# Epoch 18/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 83s 162ms/step - accuracy: 0.9712 - dice_loss: 0.0408 - loss: 0.0755 - val_accuracy: 0.9268 - val_dice_loss: 0.0826 - val_loss: 0.3173
# Epoch 19/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 82s 160ms/step - accuracy: 0.9729 - dice_loss: 0.0387 - loss: 0.0707 - val_accuracy: 0.9208 - val_dice_loss: 0.0876 - val_loss: 0.3671
# Epoch 20/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 82s 160ms/step - accuracy: 0.9732 - dice_loss: 0.0381 - loss: 0.0696 - val_accuracy: 0.9211 - val_dice_loss: 0.0869 - val_loss: 0.3584
# training completed in 1779.2492825984955 s

# %%
print(model.history.history.keys())
# Out:
# dict_keys(['accuracy', 'dice_loss', 'loss', 'val_accuracy', 'val_dice_loss', 'val_loss'])

# %%
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(model.history.history['dice_loss'])
plt.plot(model.history.history['val_dice_loss'])
plt.title('model dice loss')
plt.ylabel('dice loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
out = model.predict_segmentation(
    inp = "/kaggle/input/images_test/0016E5_07959.png"
)
plt.imshow(out)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step

# %%
from IPython.display import Image

o = model.predict_segmentation(
    inp="/kaggle/input/images_test/0016E5_07959.png",
    out_fname="/kaggle/working/out.png",
    overlay_img=True,
    show_legends=True,
    class_names = ["Sky","Building","Pole","Road","pavement","Tree","SignSymbol","Fence","Car","Pedestrian","Bicylist"]
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
Image("/kaggle/working/out.png")
