# %%
# !git clone https://github.com/rajeevratan84/image-segmentation-keras.git
# Out:
# Cloning into 'image-segmentation-keras'...
# remote: Enumerating objects: 1165, done.
# remote: Total 1165 (delta 0), reused 0 (delta 0), pack-reused 1165
# Receiving objects: 100% (1165/1165), 3.29 MiB | 15.59 MiB/s, done.
# Resolving deltas: 100% (752/752), done.

# %%
# %cd image-segmentation-keras
# !python setup.py install
# Out:
# /kaggle/working/image-segmentation-keras

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from imgaug import augmenters as iaa
from keras.callbacks import ModelCheckpoint
from IPython.display import Image
import tensorflow as tf
from tensorflow.keras import backend as K
from keras_segmentation.models.unet import vgg_unet, resnet50_unet
from tensorflow.keras.optimizers import Adam
import time
# Out:
# 2024-08-04 14:21:43.429040: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-04 14:21:43.429144: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-04 14:21:43.593226: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !pip list

# %%
image_train_list = os.listdir('/kaggle/input/self-driving-car/images_prepped_train')
anns_train_list = os.listdir('/kaggle/input/self-driving-car/annotations_prepped_train')
image_val_list = os.listdir('/kaggle/input/self-driving-car/images_prepped_test')
anns_val_list = os.listdir('/kaggle/input/self-driving-car/annotations_prepped_test')

print('number of train data pairs: ', len(set(image_train_list).intersection(anns_train_list)))
print('number of validation data pairs: ', len(set(image_val_list).intersection(anns_val_list)))
del image_train_list, anns_train_list, image_val_list, anns_val_list
# Out:
# number of train data pairs:  367
# number of validation data pairs:  101

# %%
def dice_loss(y_true, y_pred, smooth=1e-6):
    """
    Calculate Dice Loss between the ground truth and predictions.

    Parameters:
    - y_true: Ground truth labels (shape: [batch_size, height, width, num_classes])
    - y_pred: Predicted labels (shape: [batch_size, height, width, num_classes])
    - smooth: Smoothing factor to avoid division by zero

    Returns:
    - Dice Loss value
    """
    # Flatten the tensors
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(y_pred)

    # Calculate intersection and union
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f)

    # Compute Dice coefficient
    dice = (2. * intersection + smooth) / (union + smooth)

    # Return Dice Loss
    return 1 - dice

# %%
model = resnet50_unet(n_classes=30, input_height=352, input_width=480)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94653016/94653016 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
def custom_augmentation():
    return iaa.Sequential(
        [
            # apply the following augmenters to most images
#             iaa.GaussianBlur(sigma=(0.0, 0.5)),
            iaa.Fliplr(0.5), # horizontally flip 50% of all images
#           iaa.Alpha((0.0, 0.5), iaa.HistogramEqualization()),
#            iaa.GammaContrast((0.5, 2.0)),
            iaa.AllChannelsCLAHE(clip_limit=(1, 10)),
            iaa.convolutional.Sharpen(alpha=(0.0, 0.3), lightness=(0.8, 1.0))
#             iaa.Grayscale(alpha=(0.0, 1.0)),
#             iaa.pillike.FilterFindEdges(),
#             iaa.ShearX((-20, 20)),
#             iaa.AdditiveGaussianNoise(scale=(0, 0.1*255)),
#             iaa.Canny(alpha=(0.0, 0.5),colorizer=iaa.RandomColorsBinaryImageColorizer(color_true=255,color_false=0)),
        ])
# [sharpness, contrast], blur (jgn terlalu blur), saturation, hue

def image_preprocessing(image):
    image = tf.cast(image, tf.float32)
    scaled_image = image.numpy() / 255.0
    return scaled_image

# %%
from keras_segmentation.data_utils.data_loader import image_segmentation_generator, verify_segmentation_dataset
train_gen = image_segmentation_generator(images_path = "/kaggle/input/self-driving-car/images_prepped_train",
                                         segs_path = "/kaggle/input/self-driving-car/annotations_prepped_train",
                                         batch_size = 2,  
                                         n_classes = 30,
                                         input_height = 352, 
                                         input_width = 480, 
                                         output_height = model.output_height, 
                                         output_width = model.output_width,
                                         do_augment=True, 
#                                          augmentation_name=augmentation_name,
                                         custom_augmentation=custom_augmentation, 
#                                          other_inputs_paths=other_inputs_paths,
#                                          preprocessing=image_preprocessing, 
                                         read_image_type=1)

val_gen = image_segmentation_generator(images_path = "/kaggle/input/self-driving-car/images_prepped_test",
                                       segs_path = "/kaggle/input/self-driving-car/annotations_prepped_test",  
                                       batch_size = 2,
                                       n_classes = 30, 
                                       input_height = 352, 
                                       input_width = 480, 
                                       output_height = model.output_height, 
                                       output_width = model.output_width,
                                       do_augment = False,
#                                          augmentation_name=augmentation_name,
#                                        custom_augmentation=custom_augmentation, 
#                                          other_inputs_paths=other_inputs_paths,
#                                          preprocessing=image_preprocessing, 
                                       read_image_type=1)

# %%
verify_segmentation_dataset(images_path = "/kaggle/input/self-driving-car/images_prepped_train",
                            segs_path = "/kaggle/input/self-driving-car/annotations_prepped_train",
                            n_classes = 30)
verify_segmentation_dataset(images_path = "/kaggle/input/self-driving-car/images_prepped_test",
                            segs_path = "/kaggle/input/self-driving-car/annotations_prepped_test",
                            n_classes = 30)
# Out:
# 100%|██████████| 367/367 [00:08<00:00, 41.12it/s]
# Dataset verified!
# 100%|██████████| 101/101 [00:02<00:00, 40.06it/s]
# Dataset verified!
# True

# %%
checkpoint_path = "/kaggle/working/weights/resnet_unet.weights.h5"
os.makedirs(os.path.dirname(checkpoint_path), exist_ok = True)
checkpoint = ModelCheckpoint(checkpoint_path, 
                             monitor="val_dice_loss",
                             save_best_only=False,
                             save_weights_only = True,
                             mode="min")

# %%
from keras.callbacks import History
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',#dice_loss,
    metrics=[dice_loss, 'accuracy']#, tf.keras.metrics.F1Score(average = "weighted")] # f1-score, accuracy
)

start_time = time.time()
model.fit(train_gen,
          steps_per_epoch = 512,
          validation_data=val_gen,
          validation_steps=512,
          epochs = 20, # coba 20 epoch u/ cek overfitting
          callbacks=[checkpoint],
          initial_epoch=0)
print('training completed in {} s'.format(time.time()-start_time))
# Out:
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722781404.492990     123 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 165s 178ms/step - accuracy: 0.5452 - dice_loss: 0.6208 - loss: 1.9173 - val_accuracy: 0.8267 - val_dice_loss: 0.2961 - val_loss: 0.6323
# Epoch 2/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 87s 171ms/step - accuracy: 0.8935 - dice_loss: 0.1633 - loss: 0.3730 - val_accuracy: 0.8737 - val_dice_loss: 0.1714 - val_loss: 0.3860
# Epoch 3/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 88s 173ms/step - accuracy: 0.9190 - dice_loss: 0.1209 - loss: 0.2628 - val_accuracy: 0.8544 - val_dice_loss: 0.1864 - val_loss: 0.5129
# Epoch 4/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 88s 172ms/step - accuracy: 0.9371 - dice_loss: 0.0935 - loss: 0.1971 - val_accuracy: 0.9007 - val_dice_loss: 0.1217 - val_loss: 0.3377
# Epoch 5/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 88s 172ms/step - accuracy: 0.9450 - dice_loss: 0.0807 - loss: 0.1668 - val_accuracy: 0.9016 - val_dice_loss: 0.1189 - val_loss: 0.3353
# Epoch 6/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 87s 170ms/step - accuracy: 0.9503 - dice_loss: 0.0722 - loss: 0.1465 - val_accuracy: 0.9161 - val_dice_loss: 0.1014 - val_loss: 0.3027
# Epoch 7/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 86s 168ms/step - accuracy: 0.9543 - dice_loss: 0.0656 - loss: 0.1317 - val_accuracy: 0.9138 - val_dice_loss: 0.0989 - val_loss: 0.3267
# Epoch 8/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 83s 163ms/step - accuracy: 0.9566 - dice_loss: 0.0619 - loss: 0.1232 - val_accuracy: 0.9021 - val_dice_loss: 0.1195 - val_loss: 0.3736
# Epoch 9/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 81s 158ms/step - accuracy: 0.9567 - dice_loss: 0.0619 - loss: 0.1226 - val_accuracy: 0.9146 - val_dice_loss: 0.0982 - val_loss: 0.3138
# Epoch 10/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 80s 157ms/step - accuracy: 0.9617 - dice_loss: 0.0546 - loss: 0.1057 - val_accuracy: 0.9195 - val_dice_loss: 0.0934 - val_loss: 0.2969
# Epoch 11/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 80s 157ms/step - accuracy: 0.9632 - dice_loss: 0.0522 - loss: 0.1004 - val_accuracy: 0.9155 - val_dice_loss: 0.0994 - val_loss: 0.3363
# Epoch 12/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 80s 157ms/step - accuracy: 0.9640 - dice_loss: 0.0508 - loss: 0.0981 - val_accuracy: 0.9207 - val_dice_loss: 0.0910 - val_loss: 0.3113
# Epoch 13/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 80s 157ms/step - accuracy: 0.9648 - dice_loss: 0.0496 - loss: 0.0948 - val_accuracy: 0.9147 - val_dice_loss: 0.0977 - val_loss: 0.3497
# Epoch 14/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 81s 159ms/step - accuracy: 0.9668 - dice_loss: 0.0468 - loss: 0.0889 - val_accuracy: 0.9194 - val_dice_loss: 0.0915 - val_loss: 0.3065
# Epoch 15/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 82s 161ms/step - accuracy: 0.9669 - dice_loss: 0.0464 - loss: 0.0882 - val_accuracy: 0.9203 - val_dice_loss: 0.0905 - val_loss: 0.3257
# Epoch 16/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 82s 161ms/step - accuracy: 0.9681 - dice_loss: 0.0450 - loss: 0.0850 - val_accuracy: 0.8440 - val_dice_loss: 0.1810 - val_loss: 0.6047
# Epoch 17/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 82s 161ms/step - accuracy: 0.9570 - dice_loss: 0.0608 - loss: 0.1219 - val_accuracy: 0.9179 - val_dice_loss: 0.0928 - val_loss: 0.3165
# Epoch 18/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 82s 161ms/step - accuracy: 0.9711 - dice_loss: 0.0415 - loss: 0.0763 - val_accuracy: 0.9179 - val_dice_loss: 0.0923 - val_loss: 0.3388
# Epoch 19/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 82s 161ms/step - accuracy: 0.9729 - dice_loss: 0.0388 - loss: 0.0709 - val_accuracy: 0.9162 - val_dice_loss: 0.0922 - val_loss: 0.3668
# Epoch 20/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 82s 161ms/step - accuracy: 0.9729 - dice_loss: 0.0386 - loss: 0.0707 - val_accuracy: 0.9235 - val_dice_loss: 0.0848 - val_loss: 0.3324
# training completed in 1750.3984668254852 s

# %%
print(model.history.history.keys())
# Out:
# dict_keys(['accuracy', 'dice_loss', 'loss', 'val_accuracy', 'val_dice_loss', 'val_loss'])

# %%
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(model.history.history['dice_loss'])
plt.plot(model.history.history['val_dice_loss'])
plt.title('model dice loss')
plt.ylabel('dice loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# plt.plot(model.history.history['loss'])
# plt.plot(model.history.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %%
out = model.predict_segmentation(
    inp = "/kaggle/input/self-driving-car/images_prepped_test/0016E5_07959.png"
)
plt.imshow(out)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step

# %%
from IPython.display import Image

o = model.predict_segmentation(
    inp="/kaggle/input/self-driving-car/images_prepped_test/0016E5_07959.png",
    out_fname="/kaggle/working/outresnet10.png",
    overlay_img=True,
    show_legends=True,
    class_names = ["Sky","Building","Pole","Road","pavement","Tree","SignSymbol","Fence","Car","Pedestrian","Bicylist"]
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
Image("/kaggle/working/outresnet10.png")
