# %%
# !git clone https://github.com/rajeevratan84/image-segmentation-keras.git
# Out:
# Cloning into 'image-segmentation-keras'...
# remote: Enumerating objects: 1165, done.
# remote: Total 1165 (delta 0), reused 0 (delta 0), pack-reused 1165
# Receiving objects: 100% (1165/1165), 3.29 MiB | 26.31 MiB/s, done.
# Resolving deltas: 100% (752/752), done.

# %%
# %cd image-segmentation-keras
# !python setup.py install
# Out:
# /kaggle/working/image-segmentation-keras

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from imgaug import augmenters as iaa
from keras.callbacks import ModelCheckpoint
from IPython.display import Image
import tensorflow as tf
from tensorflow.keras import backend as K
from keras_segmentation.models.unet import vgg_unet, resnet50_unet
from tensorflow.keras.optimizers import Adam
import time
# Out:
# 2024-07-31 14:59:17.041870: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-31 14:59:17.041982: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-31 14:59:17.172295: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !pip list

# %%
image_train_list = os.listdir('/kaggle/input/drive-auto/images_prepped_train')
anns_train_list = os.listdir('/kaggle/input/drive-auto/annotations_prepped_train')
image_val_list = os.listdir('/kaggle/input/drive-auto/images_prepped_test')
anns_val_list = os.listdir('/kaggle/input/drive-auto/annotations_prepped_test')

print('number of train data pairs: ', len(set(image_train_list).intersection(anns_train_list)))
print('number of validation data pairs: ', len(set(image_val_list).intersection(anns_val_list)))
del image_train_list, anns_train_list, image_val_list, anns_val_list
# Out:
# number of train data pairs:  367
# number of validation data pairs:  101

# %%
def dice_loss(y_true, y_pred, smooth=1e-6):
    """
    Calculate Dice Loss between the ground truth and predictions.

    Parameters:
    - y_true: Ground truth labels (shape: [batch_size, height, width, num_classes])
    - y_pred: Predicted labels (shape: [batch_size, height, width, num_classes])
    - smooth: Smoothing factor to avoid division by zero

    Returns:
    - Dice Loss value
    """
    # Flatten the tensors
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(y_pred)

    # Calculate intersection and union
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f)

    # Compute Dice coefficient
    dice = (2. * intersection + smooth) / (union + smooth)

    # Return Dice Loss
    return 1 - dice

# %%
model = resnet50_unet(n_classes=30, input_height=352, input_width=480)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94653016/94653016 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
def custom_augmentation():
    return iaa.Sequential(
        [
            # apply the following augmenters to most images
#             iaa.GaussianBlur(sigma=(0.0, 0.5)),
            iaa.Fliplr(0.5), # horizontally flip 50% of all images
            iaa.GammaContrast((0.5, 2.0)),
            iaa.convolutional.Sharpen(alpha=(0.0, 0.2), lightness=(0.8, 1.2))
#             iaa.Grayscale(alpha=(0.0, 1.0)),
#             iaa.pillike.FilterFindEdges(),
#             iaa.ShearX((-20, 20)),
#             iaa.AdditiveGaussianNoise(scale=(0, 0.1*255)),
#             iaa.Canny(alpha=(0.0, 0.5),colorizer=iaa.RandomColorsBinaryImageColorizer(color_true=255,color_false=0)),
        ])
# [sharpness, contrast], blur (jgn terlalu blur), saturation, hue

def image_preprocessing(image):
    image = tf.cast(image, tf.float32)
    scaled_image = image.numpy() / 255.0
    return scaled_image

# %%
from keras_segmentation.data_utils.data_loader import image_segmentation_generator, verify_segmentation_dataset
train_gen = image_segmentation_generator(images_path = "/kaggle/input/drive-auto/images_prepped_train",
                                         segs_path = "/kaggle/input/drive-auto/annotations_prepped_train",
                                         batch_size = 2,  
                                         n_classes = 30,
                                         input_height = 352, 
                                         input_width = 480, 
                                         output_height = model.output_height, 
                                         output_width = model.output_width,
                                         do_augment=False, 
#                                          augmentation_name=augmentation_name,
#                                          custom_augmentation=custom_augmentation, 
#                                          other_inputs_paths=other_inputs_paths,
#                                          preprocessing=image_preprocessing, 
                                         read_image_type=1)

val_gen = image_segmentation_generator(images_path = "/kaggle/input/drive-auto/images_prepped_test",
                                       segs_path = "/kaggle/input/drive-auto/annotations_prepped_test",  
                                       batch_size = 2,
                                       n_classes = 30, 
                                       input_height = 352, 
                                       input_width = 480, 
                                       output_height = model.output_height, 
                                       output_width = model.output_width,
                                       do_augment = False,
#                                          augmentation_name=augmentation_name,
#                                          custom_augmentation=custom_augmentation, 
#                                          other_inputs_paths=other_inputs_paths,
#                                          preprocessing=image_preprocessing, 
                                       read_image_type=1)

# %%
verify_segmentation_dataset(images_path = "/kaggle/input/drive-auto/images_prepped_train",
                            segs_path = "/kaggle/input/drive-auto/annotations_prepped_train",
                            n_classes = 30)
verify_segmentation_dataset(images_path = "/kaggle/input/drive-auto/images_prepped_test",
                            segs_path = "/kaggle/input/drive-auto/annotations_prepped_test",
                            n_classes = 30)
# Out:
# 100%|██████████| 367/367 [00:03<00:00, 116.58it/s]
# Dataset verified!
# 100%|██████████| 101/101 [00:00<00:00, 112.55it/s]
# Dataset verified!
# True

# %%
checkpoint_path = "/kaggle/working/weights/resnet_unet.weights.h5"
os.makedirs(os.path.dirname(checkpoint_path), exist_ok = True)
checkpoint = ModelCheckpoint(checkpoint_path, 
                             monitor="val_dice_loss",
                             save_best_only=False,
                             save_weights_only = True,
                             mode="min")

# %%
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',#dice_loss,
    metrics=[dice_loss, 'accuracy']#, tf.keras.metrics.F1Score(average = "weighted")] # f1-score, accuracy
)

start_time = time.time()
model.fit(train_gen,
          steps_per_epoch = 512,
          validation_data=val_gen,
          validation_steps=512,
          epochs = 20, # coba 20 epoch u/ cek overfitting
          callbacks=[checkpoint],
          initial_epoch=0)
print('training completed in {} s'.format(time.time()-start_time))
# Out:
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722438434.407638     119 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 170s 184ms/step - accuracy: 0.6232 - dice_loss: 0.5492 - loss: 1.6217 - val_accuracy: 0.8681 - val_dice_loss: 0.2055 - val_loss: 0.4583
# Epoch 2/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 91s 177ms/step - accuracy: 0.9173 - dice_loss: 0.1319 - loss: 0.2885 - val_accuracy: 0.9053 - val_dice_loss: 0.1270 - val_loss: 0.3337
# Epoch 3/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 91s 178ms/step - accuracy: 0.9427 - dice_loss: 0.0883 - loss: 0.1836 - val_accuracy: 0.9221 - val_dice_loss: 0.0994 - val_loss: 0.2637
# Epoch 4/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 91s 179ms/step - accuracy: 0.9538 - dice_loss: 0.0690 - loss: 0.1390 - val_accuracy: 0.9163 - val_dice_loss: 0.0991 - val_loss: 0.2917
# Epoch 5/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 92s 179ms/step - accuracy: 0.9600 - dice_loss: 0.0586 - loss: 0.1154 - val_accuracy: 0.9191 - val_dice_loss: 0.0964 - val_loss: 0.3109
# Epoch 6/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 91s 177ms/step - accuracy: 0.9619 - dice_loss: 0.0546 - loss: 0.1076 - val_accuracy: 0.9080 - val_dice_loss: 0.1047 - val_loss: 0.3848
# Epoch 7/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 90s 175ms/step - accuracy: 0.9646 - dice_loss: 0.0503 - loss: 0.0981 - val_accuracy: 0.9243 - val_dice_loss: 0.0853 - val_loss: 0.2927
# Epoch 8/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 87s 171ms/step - accuracy: 0.9678 - dice_loss: 0.0460 - loss: 0.0880 - val_accuracy: 0.9142 - val_dice_loss: 0.0952 - val_loss: 0.3439
# Epoch 9/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 86s 168ms/step - accuracy: 0.9715 - dice_loss: 0.0410 - loss: 0.0764 - val_accuracy: 0.9164 - val_dice_loss: 0.0945 - val_loss: 0.3477
# Epoch 10/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 85s 167ms/step - accuracy: 0.9723 - dice_loss: 0.0396 - loss: 0.0739 - val_accuracy: 0.9212 - val_dice_loss: 0.0874 - val_loss: 0.3406
# Epoch 11/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 86s 167ms/step - accuracy: 0.9733 - dice_loss: 0.0380 - loss: 0.0708 - val_accuracy: 0.9200 - val_dice_loss: 0.0882 - val_loss: 0.3477
# Epoch 12/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 86s 167ms/step - accuracy: 0.9743 - dice_loss: 0.0363 - loss: 0.0677 - val_accuracy: 0.9233 - val_dice_loss: 0.0850 - val_loss: 0.3487
# Epoch 13/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 86s 167ms/step - accuracy: 0.9759 - dice_loss: 0.0346 - loss: 0.0636 - val_accuracy: 0.8853 - val_dice_loss: 0.1242 - val_loss: 0.4956
# Epoch 14/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 86s 168ms/step - accuracy: 0.9691 - dice_loss: 0.0443 - loss: 0.0857 - val_accuracy: 0.9203 - val_dice_loss: 0.0881 - val_loss: 0.3397
# Epoch 15/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 86s 167ms/step - accuracy: 0.9795 - dice_loss: 0.0303 - loss: 0.0536 - val_accuracy: 0.9194 - val_dice_loss: 0.0870 - val_loss: 0.3943
# Epoch 16/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 86s 167ms/step - accuracy: 0.9797 - dice_loss: 0.0292 - loss: 0.0529 - val_accuracy: 0.9189 - val_dice_loss: 0.0882 - val_loss: 0.3783
# Epoch 17/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 86s 167ms/step - accuracy: 0.9779 - dice_loss: 0.0310 - loss: 0.0577 - val_accuracy: 0.9164 - val_dice_loss: 0.0910 - val_loss: 0.3964
# Epoch 18/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 86s 167ms/step - accuracy: 0.9806 - dice_loss: 0.0281 - loss: 0.0505 - val_accuracy: 0.9248 - val_dice_loss: 0.0818 - val_loss: 0.3494
# Epoch 19/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 86s 168ms/step - accuracy: 0.9814 - dice_loss: 0.0268 - loss: 0.0484 - val_accuracy: 0.9183 - val_dice_loss: 0.0880 - val_loss: 0.4003
# Epoch 20/20
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 86s 167ms/step - accuracy: 0.9806 - dice_loss: 0.0277 - loss: 0.0504 - val_accuracy: 0.9200 - val_dice_loss: 0.0863 - val_loss: 0.3821
# training completed in 1830.9707298278809 s

# %%
print(model.history.history.keys())
# Out:
# dict_keys(['accuracy', 'dice_loss', 'loss', 'val_accuracy', 'val_dice_loss', 'val_loss'])

# %%
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(model.history.history['dice_loss'])
plt.plot(model.history.history['val_dice_loss'])
plt.title('model dice loss')
plt.ylabel('dice loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# plt.plot(model.history.history['loss'])
# plt.plot(model.history.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %%
out = model.predict_segmentation(
    inp = "/kaggle/input/drive-auto/images_prepped_test/0016E5_07959.png"
)
plt.imshow(out)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step

# %%
from IPython.display import Image

o = model.predict_segmentation(
    inp="/kaggle/input/drive-auto/images_prepped_test/0016E5_07959.png",
    out_fname="/kaggle/working/out.png",
    overlay_img=True,
    show_legends=True,
    class_names = ["Sky","Building","Pole","Road","pavement","Tree","SignSymbol","Fence","Car","Pedestrian","Bicylist"]
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
